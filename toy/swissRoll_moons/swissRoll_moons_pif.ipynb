# %% [markdown]
# # Toy diffusion model generating data from a complex 2-d distribution

# %% [markdown]
# ## General imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load training data

# %%
from sklearn.datasets import make_moons, make_swiss_roll
import numpy as np

x, _ = make_moons(n_samples=100000, noise=0.05)
# Make two-dimensional to easen 

# x = x[:, [0, 2]]

x = (x - x.mean()) / x.std()

x1, _ = make_swiss_roll(n_samples=100000, noise=0.5)
# Make two-dimensional to easen visualization
x1 = x1[:, [0, 2]]

x1 = (x1 - x1.mean()) / x1.std()

x = np.concatenate([x,x1],axis=0)
np.random.shuffle(x)

plt.scatter(x[:, 0], x[:, 1])

# %% [markdown]
# ## Prepare data for learning

# %%
import torch

X = torch.tensor(x, dtype=torch.float32)

# %% [markdown]
# ## Diffusion model hyperparameters

# %%
num_steps = 40  # Number of steps in the diffusion process

# %% [markdown]
# Function that noises a data point following the diffusion process

# %%
s_min = 0.8
def noise(Xbatch, t):  # t ~ [0, num_steps - 1]   t=0 means no noise
    eps = torch.randn(size=Xbatch.shape).to(Xbatch.device)
    f_t = 1 - s_min**(t/num_steps)
    u_coeff = 1 - f_t
    e_coeff = f_t
    noised = u_coeff * Xbatch + e_coeff * eps
    return noised, eps

def denoise(noised, eps, t):  # t ~ [0, num_steps - 1]   t=0 means no noise
    f_t = 1 - s_min**(t/num_steps)
    u_coeff = 1 - f_t
    e_coeff = f_t
    denoised = 1 / u_coeff * (noised - e_coeff * eps)
    return denoised

# %% [markdown]
# Test noising the training data

# %%
noiselevel = 20

noised, eps = noise(X, torch.full([len(X), 1], fill_value=noiselevel))
plt.scatter(noised[:, 0], noised[:, 1], marker="*", alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.legend(["Noised data", "Original data"])
plt.show()

# %% [markdown]
# Since we know the noise we just added, we can recover the original data as follows:

# %%
denoised = denoise(noised, eps, noiselevel)
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.scatter(denoised[:, 0], denoised[:, 1], marker="1", alpha=0.5)
plt.legend(["Original data", "Recovered original data"])
plt.show()

# %% [markdown]
# We can also check numerically that the result is the same

# %%
X - denoised
# Out:
# tensor([[ 0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00, -2.9802e-08],
#         ...,
#         [-1.5832e-08,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00],
#         [-1.1921e-07,  0.0000e+00]])

# %% [markdown]
# ## Diffusion network

# %% [markdown]
# Now we define a pytorch network that will learn to predict the noise component from noised data.

# %%
import torch.nn as nn

class Block(nn.Module):
    def __init__(self, nunits):
        super().__init__()
        self.linear = nn.Linear(nunits, nunits)
        
    def forward(self, x: torch.Tensor):
        x = self.linear(x)
        x = nn.functional.relu(x)
        return x
        
    
class Toy_Model(nn.Module):
    def __init__(self, nfeatures: int, nblocks: int = 2, nunits: int = 64):
        super().__init__()
        
        self.inblock = nn.Linear(nfeatures+1, nunits)
        self.midblocks = nn.ModuleList([Block(nunits) for _ in range(nblocks)])
        self.outblock = nn.Linear(nunits, nfeatures)

    def forward(self, x: torch.Tensor, t: torch.Tensor) -> torch.Tensor:
        val = torch.hstack([x, t])  # Add t to inputs
        val = self.inblock(val)
        for midblock in self.midblocks:
            val = midblock(val)
        val = self.outblock(val)
        return val

# %% [markdown]
# Let's create a model with 4 inner blocks, which is enough for this problem.

# %%
model = Toy_Model(nfeatures=2, nblocks=4)

device = "cuda"
model = model.to(device)

model
# Out:
# Toy_Model(
#   (inblock): Linear(in_features=3, out_features=64, bias=True)
#   (midblocks): ModuleList(
#     (0-3): 4 x Block(
#       (linear): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (outblock): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# ## Train denoising network

# %%
import torch.optim as optim

nepochs = 100
batch_size = 2048

loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.LinearLR(optimizer, start_factor=1.0, end_factor=0.01, total_iters=nepochs)

for epoch in range(nepochs):
    epoch_loss = steps = 0
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        timesteps = torch.randint(0, num_steps, size=[len(Xbatch), 1])
        noised, eps = noise(Xbatch, timesteps)
        predicted_noise = model(noised.to(device), timesteps.to(device))
        loss = loss_fn(predicted_noise, eps.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss
        steps += 1
    print(f"Epoch {epoch} loss = {epoch_loss / steps}")
# Out:
# Epoch 0 loss = 0.9940705895423889
# Epoch 1 loss = 0.9875685572624207
# Epoch 2 loss = 0.9823070168495178
# Epoch 3 loss = 0.9722458720207214
# Epoch 4 loss = 0.9628953337669373
# Epoch 5 loss = 0.9443219900131226
# Epoch 6 loss = 0.9320383667945862
# Epoch 7 loss = 0.9132353663444519
# Epoch 8 loss = 0.909640908241272
# Epoch 9 loss = 0.8991802334785461
# Epoch 10 loss = 0.8827613592147827
# Epoch 11 loss = 0.8655399084091187
# Epoch 12 loss = 0.8596858978271484
# Epoch 13 loss = 0.8466464281082153
# Epoch 14 loss = 0.8445165157318115
# Epoch 15 loss = 0.830933690071106
# Epoch 16 loss = 0.8243725895881653
# Epoch 17 loss = 0.8184418082237244
# Epoch 18 loss = 0.8154014945030212
# Epoch 19 loss = 0.8173429369926453
# Epoch 20 loss = 0.8165461421012878
# Epoch 21 loss = 0.8155817985534668
# Epoch 22 loss = 0.8111664056777954
# Epoch 23 loss = 0.8137009739875793
# Epoch 24 loss = 0.8057193160057068
# Epoch 25 loss = 0.8104550838470459
# Epoch 26 loss = 0.8103641271591187
# Epoch 27 loss = 0.8021973967552185
# Epoch 28 loss = 0.8020612001419067
# Epoch 29 loss = 0.802406907081604
# Epoch 30 loss = 0.8035932779312134
# Epoch 31 loss = 0.8023039698600769
# Epoch 32 loss = 0.8002561926841736
# Epoch 33 loss = 0.8018355965614319
# Epoch 34 loss = 0.8023408055305481
# Epoch 35 loss = 0.7983834743499756
# Epoch 36 loss = 0.8016954660415649
# Epoch 37 loss = 0.7978591918945312
# Epoch 38 loss = 0.7991227507591248
# Epoch 39 loss = 0.8004684448242188
# Epoch 40 loss = 0.8021401166915894
# Epoch 41 loss = 0.7954537868499756
# Epoch 42 loss = 0.8010304570198059
# Epoch 43 loss = 0.7997568845748901
# Epoch 44 loss = 0.7987990975379944
# Epoch 45 loss = 0.7986850738525391
# Epoch 46 loss = 0.7993234992027283
# Epoch 47 loss = 0.7948247790336609
# Epoch 48 loss = 0.795512855052948
# Epoch 49 loss = 0.794143795967102
# Epoch 50 loss = 0.7937526106834412
# Epoch 51 loss = 0.7977434396743774
# Epoch 52 loss = 0.7937113046646118
# Epoch 53 loss = 0.7964932322502136
# Epoch 54 loss = 0.7940672636032104
# Epoch 55 loss = 0.7944231629371643
# Epoch 56 loss = 0.790674090385437
# Epoch 57 loss = 0.7999190092086792
# Epoch 58 loss = 0.799022912979126
# Epoch 59 loss = 0.7924909591674805
# Epoch 60 loss = 0.7937349677085876
# Epoch 61 loss = 0.7939420342445374
# Epoch 62 loss = 0.7990550398826599
# Epoch 63 loss = 0.7952637672424316
# Epoch 64 loss = 0.7907677292823792
# Epoch 65 loss = 0.7919933199882507
# Epoch 66 loss = 0.7938858866691589
# Epoch 67 loss = 0.7938448190689087
# Epoch 68 loss = 0.7912812232971191
# Epoch 69 loss = 0.7910512685775757
# Epoch 70 loss = 0.7932465076446533
# Epoch 71 loss = 0.7910534739494324
# Epoch 72 loss = 0.7934995293617249
# Epoch 73 loss = 0.7901257872581482
# Epoch 74 loss = 0.7927093505859375
# Epoch 75 loss = 0.7881425023078918
# Epoch 76 loss = 0.7939909100532532
# Epoch 77 loss = 0.7941253781318665
# Epoch 78 loss = 0.7919900417327881
# Epoch 79 loss = 0.793475329875946
# Epoch 80 loss = 0.7907865643501282
# Epoch 81 loss = 0.7895339727401733
# Epoch 82 loss = 0.7920486927032471
# Epoch 83 loss = 0.7920916676521301
# Epoch 84 loss = 0.7910258173942566
# Epoch 85 loss = 0.7894679307937622
# Epoch 86 loss = 0.7948131561279297
# Epoch 87 loss = 0.7927048206329346
# Epoch 88 loss = 0.7897196412086487
# Epoch 89 loss = 0.7871676087379456
# Epoch 90 loss = 0.7935148477554321
# Epoch 91 loss = 0.7900741696357727
# Epoch 92 loss = 0.7892135977745056
# Epoch 93 loss = 0.7905438542366028
# Epoch 94 loss = 0.7911450266838074
# Epoch 95 loss = 0.7881655097007751
# Epoch 96 loss = 0.7910576462745667
# Epoch 97 loss = 0.7889285087585449
# Epoch 98 loss = 0.792518675327301
# Epoch 99 loss = 0.7891615629196167

# %% [markdown]
# ## Sampling algorithm

# %% [markdown]
# We will use the classic DDPM sampler, defined as follows

# %%
def sample(model, nsamples, nfeatures):
    """Sampler following the Denoising Diffusion Probabilistic Models method by Ho et al (Algorithm 2)"""
    with torch.no_grad():
        x = torch.randn(size=(nsamples, nfeatures)).to(device)
        xt = [x]
        for t in range(num_steps-1, 0, -1):
            predicted_noise = model(x, torch.full([nsamples, 1], t).to(device))

            x0  = denoise(x, predicted_noise, torch.tensor(t).to(device))

            if t > 1:
                x,_ = noise(x0, torch.tensor(t-1).to(device))
            xt += [x]
        return x, xt

# %% [markdown]
# ## Test generation

# %% [markdown]
# Let's generate 10K samples of the learned distribution using the diffusion model we just created

# %%
Xgen, Xgen_hist = sample(model, 10000, 2)
Xgen = Xgen.cpu()
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.scatter(Xgen[:, 0], Xgen[:, 1], marker="1", alpha=0.5)
plt.legend(["Original data", "Generated data"])
plt.xlim(-2.4, 2.4)
plt.ylim(-2.4, 2.4)
plt.xticks([-2, -1, 0, 1, 2])
plt.yticks([-2, -1, 0, 1, 2])
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
