# %% [markdown]
# # Toy diffusion model generating data from a complex 2-d distribution

# %% [markdown]
# ## General imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load training data

# %%
from sklearn.datasets import make_swiss_roll

x, _ = make_swiss_roll(n_samples=100000, noise=0.5)
# Make two-dimensional to easen visualization
x = x[:, [0, 2]]

x = (x - x.mean()) / x.std()

plt.scatter(x[:, 0], x[:, 1])

# %% [markdown]
# ## Prepare data for learning

# %%
import torch

X = torch.tensor(x, dtype=torch.float32)

# %% [markdown]
# ## Diffusion model hyperparameters

# %%
num_steps = 40  # Number of steps in the diffusion process

# %% [markdown]
# Function that noises a data point following the diffusion process

# %%
from torch.distributions import Laplace

s_min = 0.8
def noise(Xbatch, t):  # t ~ [0, num_steps - 1]   t=0 means no noise
    f_t = 1 - s_min**(t/num_steps)
    u_coeff = 1 - f_t
    e_coeff = f_t + 1e-5
    theta_t = (u_coeff * Xbatch + e_coeff * 0, (u_coeff * 0 + e_coeff * 1) * torch.ones_like(Xbatch))
    noised = Laplace(theta_t[0],theta_t[1]).sample().to(Xbatch.device)
    eps = 1 / e_coeff * (noised - u_coeff * Xbatch)
    return noised, eps

def denoise(noised, eps, t):  # t ~ [0, num_steps - 1]   t=0 means no noise
    f_t = 1 - s_min**(t/num_steps)
    u_coeff = 1 - f_t
    e_coeff = f_t + 1e-5
    denoised = 1 / u_coeff * (noised - e_coeff * eps)
    return denoised

# %% [markdown]
# Test noising the training data

# %%
noiselevel = 20

noised, eps = noise(X, torch.full([len(X), 1], fill_value=noiselevel))
plt.scatter(noised[:, 0], noised[:, 1], marker="*", alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.legend(["Noised data", "Original data"])
plt.show()

# %% [markdown]
# Since we know the noise we just added, we can recover the original data as follows:

# %%
denoised = denoise(noised, eps, noiselevel)
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.scatter(denoised[:, 0], denoised[:, 1], marker="1", alpha=0.5)
plt.legend(["Original data", "Recovered original data"])
plt.show()

# %% [markdown]
# We can also check numerically that the result is the same

# %%
X - denoised
# Out:
# tensor([[-7.4506e-09,  0.0000e+00],
#         [ 5.9605e-08,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00],
#         ...,
#         [-1.1921e-07,  0.0000e+00],
#         [ 0.0000e+00,  1.1921e-07],
#         [ 0.0000e+00,  0.0000e+00]])

# %% [markdown]
# ## Diffusion network

# %% [markdown]
# Now we define a pytorch network that will learn to predict the noise component from noised data.

# %%
import torch.nn as nn

class Block(nn.Module):
    def __init__(self, nunits):
        super().__init__()
        self.linear = nn.Linear(nunits, nunits)
        
    def forward(self, x: torch.Tensor):
        x = self.linear(x)
        x = nn.functional.relu(x)
        return x
        
    
class Toy_Model(nn.Module):
    def __init__(self, nfeatures: int, nblocks: int = 2, nunits: int = 64):
        super().__init__()
        
        self.inblock = nn.Linear(nfeatures+1, nunits)
        self.midblocks = nn.ModuleList([Block(nunits) for _ in range(nblocks)])
        self.outblock = nn.Linear(nunits, nfeatures)

    def forward(self, x: torch.Tensor, t: torch.Tensor) -> torch.Tensor:
        val = torch.hstack([x, t])  # Add t to inputs
        val = self.inblock(val)
        for midblock in self.midblocks:
            val = midblock(val)
        val = self.outblock(val)
        return val

# %% [markdown]
# Let's create a model with 4 inner blocks, which is enough for this problem.

# %%
model = Toy_Model(nfeatures=2, nblocks=4)

device = "cuda"
model = model.to(device)

model
# Out:
# Toy_Model(
#   (inblock): Linear(in_features=3, out_features=64, bias=True)
#   (midblocks): ModuleList(
#     (0-3): 4 x Block(
#       (linear): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (outblock): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# ## Train denoising network

# %%
import torch.optim as optim

nepochs = 100
batch_size = 2048

loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.LinearLR(optimizer, start_factor=1.0, end_factor=0.01, total_iters=nepochs)

for epoch in range(nepochs):
    epoch_loss = steps = 0
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        timesteps = torch.randint(0, num_steps, size=[len(Xbatch), 1])
        noised, eps = noise(Xbatch, timesteps)
        predicted_noise = model(noised.to(device), timesteps.to(device))
        loss = loss_fn(predicted_noise, eps.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss
        steps += 1
    print(f"Epoch {epoch} loss = {epoch_loss / steps}")
# Out:
# Epoch 0 loss = 1.9885601997375488
# Epoch 1 loss = 1.9502393007278442
# Epoch 2 loss = 1.9394670724868774
# Epoch 3 loss = 1.9493821859359741
# Epoch 4 loss = 1.9317466020584106
# Epoch 5 loss = 1.9194891452789307
# Epoch 6 loss = 1.9461578130722046
# Epoch 7 loss = 1.902610421180725
# Epoch 8 loss = 1.8913774490356445
# Epoch 9 loss = 1.862828016281128
# Epoch 10 loss = 1.8431272506713867
# Epoch 11 loss = 1.8150242567062378
# Epoch 12 loss = 1.7762625217437744
# Epoch 13 loss = 1.762361764907837
# Epoch 14 loss = 1.7374463081359863
# Epoch 15 loss = 1.708785057067871
# Epoch 16 loss = 1.6921947002410889
# Epoch 17 loss = 1.6728705167770386
# Epoch 18 loss = 1.7111890316009521
# Epoch 19 loss = 1.63114333152771
# Epoch 20 loss = 1.6244854927062988
# Epoch 21 loss = 1.6172759532928467
# Epoch 22 loss = 1.5867925882339478
# Epoch 23 loss = 1.5827842950820923
# Epoch 24 loss = 1.584916114807129
# Epoch 25 loss = 1.5719456672668457
# Epoch 26 loss = 1.584667444229126
# Epoch 27 loss = 1.570561170578003
# Epoch 28 loss = 1.5503695011138916
# Epoch 29 loss = 1.562045931816101
# Epoch 30 loss = 1.5361039638519287
# Epoch 31 loss = 1.5401324033737183
# Epoch 32 loss = 1.5316258668899536
# Epoch 33 loss = 1.5339295864105225
# Epoch 34 loss = 1.5310202836990356
# Epoch 35 loss = 1.5456359386444092
# Epoch 36 loss = 1.5242743492126465
# Epoch 37 loss = 1.527941346168518
# Epoch 38 loss = 1.5429073572158813
# Epoch 39 loss = 1.5243072509765625
# Epoch 40 loss = 1.526786208152771
# Epoch 41 loss = 1.5322531461715698
# Epoch 42 loss = 1.542809009552002
# Epoch 43 loss = 1.5257686376571655
# Epoch 44 loss = 1.5293471813201904
# Epoch 45 loss = 1.5200557708740234
# Epoch 46 loss = 1.5218490362167358
# Epoch 47 loss = 1.4954499006271362
# Epoch 48 loss = 1.5017509460449219
# Epoch 49 loss = 1.496176838874817
# Epoch 50 loss = 1.5121569633483887
# Epoch 51 loss = 1.5001230239868164
# Epoch 52 loss = 1.518523931503296
# Epoch 53 loss = 1.5238735675811768
# Epoch 54 loss = 1.5219839811325073
# Epoch 55 loss = 1.50955331325531
# Epoch 56 loss = 1.5160717964172363
# Epoch 57 loss = 1.522990107536316
# Epoch 58 loss = 1.5092850923538208
# Epoch 59 loss = 1.5136992931365967
# Epoch 60 loss = 1.5114421844482422
# Epoch 61 loss = 1.4937039613723755
# Epoch 62 loss = 1.5126135349273682
# Epoch 63 loss = 1.5152318477630615
# Epoch 64 loss = 1.4989309310913086
# Epoch 65 loss = 1.5112299919128418
# Epoch 66 loss = 1.514983057975769
# Epoch 67 loss = 1.5129213333129883
# Epoch 68 loss = 1.5102686882019043
# Epoch 69 loss = 1.5123908519744873
# Epoch 70 loss = 1.527630090713501
# Epoch 71 loss = 1.5173410177230835
# Epoch 72 loss = 1.5039827823638916
# Epoch 73 loss = 1.4988561868667603
# Epoch 74 loss = 1.5124218463897705
# Epoch 75 loss = 1.4992244243621826
# Epoch 76 loss = 1.5121361017227173
# Epoch 77 loss = 1.5215258598327637
# Epoch 78 loss = 1.527337908744812
# Epoch 79 loss = 1.514526605606079
# Epoch 80 loss = 1.5221091508865356
# Epoch 81 loss = 1.5030125379562378
# Epoch 82 loss = 1.5034105777740479
# Epoch 83 loss = 1.4940780401229858
# Epoch 84 loss = 1.5094748735427856
# Epoch 85 loss = 1.4994558095932007
# Epoch 86 loss = 1.5108537673950195
# Epoch 87 loss = 1.4972507953643799
# Epoch 88 loss = 1.5073055028915405
# Epoch 89 loss = 1.5003713369369507
# Epoch 90 loss = 1.5049247741699219
# Epoch 91 loss = 1.495354413986206
# Epoch 92 loss = 1.5079007148742676
# Epoch 93 loss = 1.5143836736679077
# Epoch 94 loss = 1.5085595846176147
# Epoch 95 loss = 1.4991236925125122
# Epoch 96 loss = 1.499023199081421
# Epoch 97 loss = 1.4983525276184082
# Epoch 98 loss = 1.4988714456558228
# Epoch 99 loss = 1.4725323915481567

# %% [markdown]
# ## Sampling algorithm

# %% [markdown]
# We will use the classic DDPM sampler, defined as follows

# %%
def sample(model, nsamples, nfeatures):
    """Sampler following the Denoising Diffusion Probabilistic Models method by Ho et al (Algorithm 2)"""
    with torch.no_grad():
        x = torch.randn(size=(nsamples, nfeatures)).to(device)
        xt = [x]
        for t in range(num_steps-1, 0, -1):
            predicted_noise = model(x, torch.full([nsamples, 1], t).to(device))

            x0  = denoise(x, predicted_noise, torch.tensor(t).to(device))

            if t > 1:
                x,_ = noise(x0, torch.tensor(t-1).to(device))
            xt += [x]
        return x, xt

# %% [markdown]
# ## Test generation

# %% [markdown]
# Let's generate 10K samples of the learned distribution using the diffusion model we just created

# %%
Xgen, Xgen_hist = sample(model, 10000, 2)
Xgen = Xgen.cpu()
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.scatter(Xgen[:, 0], Xgen[:, 1], marker="1", alpha=0.5)
plt.legend(["Original data", "Generated data"])
plt.xlim(-2.4, 2.4)
plt.ylim(-2.4, 2.4)
plt.xticks([-2, -1, 0, 1, 2])
plt.yticks([-2, -1, 0, 1, 2])
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
