# %% [markdown]
# # Toy diffusion model generating data from a complex 2-d distribution

# %% [markdown]
# ## General imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load training data

# %%
from sklearn.datasets import make_swiss_roll

x, _ = make_swiss_roll(n_samples=100000, noise=0.5)
# Make two-dimensional to easen visualization
x = x[:, [0, 2]]

x = (x - x.mean()) / x.std()

plt.scatter(x[:, 0], x[:, 1])

# %% [markdown]
# ## Prepare data for learning

# %%
import torch

X = torch.tensor(x, dtype=torch.float32)

# %% [markdown]
# ## Diffusion model hyperparameters

# %%
num_steps = 40  # Number of steps in the diffusion process

# %% [markdown]
# Function that noises a data point following the diffusion process

# %%
s_min = 0.05
def noise(Xbatch, t):  # t ~ [0, num_steps - 1]   t=0 means no noise
    eps = torch.randn(size=Xbatch.shape).to(Xbatch.device)
    u_coeff = (1 - s_min ** (2*(1-t / num_steps)))
    e_coeff = (u_coeff * (1 - u_coeff)) ** 0.5
    noised = u_coeff * Xbatch + e_coeff * eps
    return noised, eps

def denoise(noised, eps, t):  # t ~ [0, num_steps - 1]   t=0 means no noise
    u_coeff = (1 - s_min ** (2*(1-t / num_steps)))
    e_coeff = (u_coeff * (1 - u_coeff)) ** 0.5
    denoised = 1 / u_coeff * (noised - e_coeff * eps)
    return denoised

# %% [markdown]
# Test noising the training data

# %%
noiselevel = 20

noised, eps = noise(X, torch.full([len(X), 1], fill_value=noiselevel))
plt.scatter(noised[:, 0], noised[:, 1], marker="*", alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.legend(["Noised data", "Original data"])
plt.show()

# %% [markdown]
# Since we know the noise we just added, we can recover the original data as follows:

# %%
denoised = denoise(noised, eps, noiselevel)
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.scatter(denoised[:, 0], denoised[:, 1], marker="1", alpha=0.5)
plt.legend(["Original data", "Recovered original data"])
plt.show()

# %% [markdown]
# We can also check numerically that the result is the same

# %%
X - denoised
# Out:
# tensor([[ 0.0000e+00,  0.0000e+00],
#         [-5.5879e-08, -1.1921e-07],
#         [-2.9802e-08,  0.0000e+00],
#         ...,
#         [-5.9605e-08,  0.0000e+00],
#         [ 0.0000e+00, -5.9605e-08],
#         [ 5.9605e-08,  0.0000e+00]])

# %% [markdown]
# ## Diffusion network

# %% [markdown]
# Now we define a pytorch network that will learn to predict the noise component from noised data.

# %%
import torch.nn as nn

class Block(nn.Module):
    def __init__(self, nunits):
        super().__init__()
        self.linear = nn.Linear(nunits, nunits)
        
    def forward(self, x: torch.Tensor):
        x = self.linear(x)
        x = nn.functional.relu(x)
        return x
        
    
class Toy_Model(nn.Module):
    def __init__(self, nfeatures: int, nblocks: int = 2, nunits: int = 64):
        super().__init__()
        
        self.inblock = nn.Linear(nfeatures+1, nunits)
        self.midblocks = nn.ModuleList([Block(nunits) for _ in range(nblocks)])
        self.outblock = nn.Linear(nunits, nfeatures)

    def forward(self, x: torch.Tensor, t: torch.Tensor) -> torch.Tensor:
        val = torch.hstack([x, t])  # Add t to inputs
        val = self.inblock(val)
        for midblock in self.midblocks:
            val = midblock(val)
        val = self.outblock(val)
        return val

# %% [markdown]
# Let's create a model with 4 inner blocks, which is enough for this problem.

# %%
model = Toy_Model(nfeatures=2, nblocks=4)

device = "cuda"
model = model.to(device)

model
# Out:
# Toy_Model(
#   (inblock): Linear(in_features=3, out_features=64, bias=True)
#   (midblocks): ModuleList(
#     (0-3): 4 x Block(
#       (linear): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (outblock): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# ## Train denoising network

# %%
import torch.optim as optim

nepochs = 100
batch_size = 2048

loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.LinearLR(optimizer, start_factor=1.0, end_factor=0.01, total_iters=nepochs)

for epoch in range(nepochs):
    epoch_loss = steps = 0
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        timesteps = torch.randint(0, num_steps, size=[len(Xbatch), 1])
        noised, eps = noise(Xbatch, timesteps)
        predicted_noise = model(noised.to(device), timesteps.to(device))
        loss = loss_fn(predicted_noise, eps.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss
        steps += 1
    print(f"Epoch {epoch} loss = {epoch_loss / steps}")
# Out:
# Epoch 0 loss = 0.9763336777687073
# Epoch 1 loss = 0.9076346158981323
# Epoch 2 loss = 0.8935059905052185
# Epoch 3 loss = 0.8739666938781738
# Epoch 4 loss = 0.8504123091697693
# Epoch 5 loss = 0.8148272633552551
# Epoch 6 loss = 0.7886790037155151
# Epoch 7 loss = 0.7602376937866211
# Epoch 8 loss = 0.7372071743011475
# Epoch 9 loss = 0.7123510241508484
# Epoch 10 loss = 0.6922381520271301
# Epoch 11 loss = 0.6787521839141846
# Epoch 12 loss = 0.6745156645774841
# Epoch 13 loss = 0.6699970364570618
# Epoch 14 loss = 0.6666985154151917
# Epoch 15 loss = 0.659722089767456
# Epoch 16 loss = 0.660305917263031
# Epoch 17 loss = 0.6628910899162292
# Epoch 18 loss = 0.6621472239494324
# Epoch 19 loss = 0.6638204455375671
# Epoch 20 loss = 0.6559135913848877
# Epoch 21 loss = 0.6562517285346985
# Epoch 22 loss = 0.6612727046012878
# Epoch 23 loss = 0.664508581161499
# Epoch 24 loss = 0.6599847078323364
# Epoch 25 loss = 0.6530859470367432
# Epoch 26 loss = 0.6599130034446716
# Epoch 27 loss = 0.6538208723068237
# Epoch 28 loss = 0.652313232421875
# Epoch 29 loss = 0.6608794927597046
# Epoch 30 loss = 0.6521168947219849
# Epoch 31 loss = 0.65224289894104
# Epoch 32 loss = 0.6582927703857422
# Epoch 33 loss = 0.6599368453025818
# Epoch 34 loss = 0.651422381401062
# Epoch 35 loss = 0.6565476059913635
# Epoch 36 loss = 0.6503618955612183
# Epoch 37 loss = 0.6573521494865417
# Epoch 38 loss = 0.6586132049560547
# Epoch 39 loss = 0.655806839466095
# Epoch 40 loss = 0.6541543006896973
# Epoch 41 loss = 0.6589980721473694
# Epoch 42 loss = 0.6509666442871094
# Epoch 43 loss = 0.6516887545585632
# Epoch 44 loss = 0.6507114768028259
# Epoch 45 loss = 0.658047080039978
# Epoch 46 loss = 0.6535996198654175
# Epoch 47 loss = 0.6551015973091125
# Epoch 48 loss = 0.6530988812446594
# Epoch 49 loss = 0.6464838981628418
# Epoch 50 loss = 0.6500349640846252
# Epoch 51 loss = 0.6472511291503906
# Epoch 52 loss = 0.6537482738494873
# Epoch 53 loss = 0.654897928237915
# Epoch 54 loss = 0.6560860872268677
# Epoch 55 loss = 0.6586733460426331
# Epoch 56 loss = 0.6501154899597168
# Epoch 57 loss = 0.6538589000701904
# Epoch 58 loss = 0.6521015167236328
# Epoch 59 loss = 0.6528370976448059
# Epoch 60 loss = 0.6478431820869446
# Epoch 61 loss = 0.6498580574989319
# Epoch 62 loss = 0.6495670080184937
# Epoch 63 loss = 0.6504035592079163
# Epoch 64 loss = 0.6583447456359863
# Epoch 65 loss = 0.6473650336265564
# Epoch 66 loss = 0.6543399691581726
# Epoch 67 loss = 0.6555479764938354
# Epoch 68 loss = 0.6505913734436035
# Epoch 69 loss = 0.6508219242095947
# Epoch 70 loss = 0.6473605036735535
# Epoch 71 loss = 0.6529960632324219
# Epoch 72 loss = 0.6503578424453735
# Epoch 73 loss = 0.6476312875747681
# Epoch 74 loss = 0.6499886512756348
# Epoch 75 loss = 0.6509420871734619
# Epoch 76 loss = 0.6521587371826172
# Epoch 77 loss = 0.6497311592102051
# Epoch 78 loss = 0.6523212790489197
# Epoch 79 loss = 0.6486175656318665
# Epoch 80 loss = 0.6526188254356384
# Epoch 81 loss = 0.6539199948310852
# Epoch 82 loss = 0.6551758050918579
# Epoch 83 loss = 0.6519314646720886
# Epoch 84 loss = 0.6466814279556274
# Epoch 85 loss = 0.6459647417068481
# Epoch 86 loss = 0.6500580906867981
# Epoch 87 loss = 0.6485830545425415
# Epoch 88 loss = 0.6556406617164612
# Epoch 89 loss = 0.6510989665985107
# Epoch 90 loss = 0.6479296684265137
# Epoch 91 loss = 0.6509588956832886
# Epoch 92 loss = 0.6500231027603149
# Epoch 93 loss = 0.6480636596679688
# Epoch 94 loss = 0.6491994857788086
# Epoch 95 loss = 0.6489017009735107
# Epoch 96 loss = 0.6488705277442932
# Epoch 97 loss = 0.6489002108573914
# Epoch 98 loss = 0.6500757336616516
# Epoch 99 loss = 0.6478028297424316

# %% [markdown]
# ## Sampling algorithm

# %% [markdown]
# We will use the classic DDPM sampler, defined as follows

# %%
def sample(model, nsamples, nfeatures):
    """Sampler following the Denoising Diffusion Probabilistic Models method by Ho et al (Algorithm 2)"""
    with torch.no_grad():
        x = torch.randn(size=(nsamples, nfeatures)).to(device)
        xt = [x]
        for t in range(num_steps-1, 0, -1):
            predicted_noise = model(x, torch.full([nsamples, 1], t).to(device))

            x0  = denoise(x, predicted_noise, torch.tensor(t).to(device))

            if t > 1:
                x,_ = noise(x0, torch.tensor(t-1).to(device))
            xt += [x]
        return x, xt

# %% [markdown]
# ## Test generation

# %% [markdown]
# Let's generate 10K samples of the learned distribution using the diffusion model we just created

# %%
Xgen, Xgen_hist = sample(model, 10000, 2)
Xgen = Xgen.cpu()
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.scatter(Xgen[:, 0], Xgen[:, 1], marker="1", alpha=0.5)
plt.legend(["Original data", "Generated data"])
plt.xlim(-2.4, 2.4)
plt.ylim(-2.4, 2.4)
plt.xticks([-2, -1, 0, 1, 2])
plt.yticks([-2, -1, 0, 1, 2])
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
