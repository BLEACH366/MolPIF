# %% [markdown]
# # Toy diffusion model generating data from a complex 2-d distribution

# %% [markdown]
# ## General imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load training data

# %%
from sklearn.datasets import make_swiss_roll

x, _ = make_swiss_roll(n_samples=100000, noise=0.5)
# Make two-dimensional to easen visualization
x = x[:, [0, 2]]

x = (x - x.mean()) / x.std()

plt.scatter(x[:, 0], x[:, 1])

# %% [markdown]
# ## Prepare data for learning

# %%
import torch

X = torch.tensor(x, dtype=torch.float32)

# %% [markdown]
# ## Diffusion model hyperparameters

# %%
num_steps = 40  # Number of steps in the diffusion process

# %% [markdown]
# Function that noises a data point following the diffusion process

# %%
s_min = 0.6
def noise(Xbatch, t):  # t ~ [0, num_steps - 1]   t=0 means no noise
    eps = torch.randn(size=Xbatch.shape).to(Xbatch.device)
    f_t = 1 - s_min**(t/num_steps)
    u_coeff = 1 - f_t
    e_coeff = f_t
    noised = u_coeff * Xbatch + e_coeff * eps
    return noised, eps

def denoise(noised, eps, t):  # t ~ [0, num_steps - 1]   t=0 means no noise
    f_t = 1 - s_min**(t/num_steps)
    u_coeff = 1 - f_t
    e_coeff = f_t
    denoised = 1 / u_coeff * (noised - e_coeff * eps)
    return denoised

# %% [markdown]
# Test noising the training data

# %%
noiselevel = 20

noised, eps = noise(X, torch.full([len(X), 1], fill_value=noiselevel))
plt.scatter(noised[:, 0], noised[:, 1], marker="*", alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.legend(["Noised data", "Original data"])
plt.show()

# %% [markdown]
# Since we know the noise we just added, we can recover the original data as follows:

# %%
denoised = denoise(noised, eps, noiselevel)
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.scatter(denoised[:, 0], denoised[:, 1], marker="1", alpha=0.5)
plt.legend(["Original data", "Recovered original data"])
plt.show()

# %% [markdown]
# We can also check numerically that the result is the same

# %%
X - denoised
# Out:
# tensor([[-1.1921e-07,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00],
#         ...,
#         [ 1.1921e-07,  0.0000e+00],
#         [ 1.4901e-08,  0.0000e+00],
#         [ 0.0000e+00,  1.4901e-08]])

# %% [markdown]
# ## Diffusion network

# %% [markdown]
# Now we define a pytorch network that will learn to predict the noise component from noised data.

# %%
import torch.nn as nn

class Block(nn.Module):
    def __init__(self, nunits):
        super().__init__()
        self.linear = nn.Linear(nunits, nunits)
        
    def forward(self, x: torch.Tensor):
        x = self.linear(x)
        x = nn.functional.relu(x)
        return x
        
    
class Toy_Model(nn.Module):
    def __init__(self, nfeatures: int, nblocks: int = 2, nunits: int = 64):
        super().__init__()
        
        self.inblock = nn.Linear(nfeatures+1, nunits)
        self.midblocks = nn.ModuleList([Block(nunits) for _ in range(nblocks)])
        self.outblock = nn.Linear(nunits, nfeatures)

    def forward(self, x: torch.Tensor, t: torch.Tensor) -> torch.Tensor:
        val = torch.hstack([x, t])  # Add t to inputs
        val = self.inblock(val)
        for midblock in self.midblocks:
            val = midblock(val)
        val = self.outblock(val)
        return val

# %% [markdown]
# Let's create a model with 4 inner blocks, which is enough for this problem.

# %%
model = Toy_Model(nfeatures=2, nblocks=4)

device = "cuda"
model = model.to(device)

model
# Out:
# Toy_Model(
#   (inblock): Linear(in_features=3, out_features=64, bias=True)
#   (midblocks): ModuleList(
#     (0-3): 4 x Block(
#       (linear): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (outblock): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# ## Train denoising network

# %%
import torch.optim as optim

nepochs = 100
batch_size = 2048

loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.LinearLR(optimizer, start_factor=1.0, end_factor=0.01, total_iters=nepochs)

for epoch in range(nepochs):
    epoch_loss = steps = 0
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        timesteps = torch.randint(0, num_steps, size=[len(Xbatch), 1])
        noised, eps = noise(Xbatch, timesteps)
        predicted_noise = model(noised.to(device), timesteps.to(device))
        loss = loss_fn(predicted_noise, eps.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss
        steps += 1
    print(f"Epoch {epoch} loss = {epoch_loss / steps}")
# Out:
# Epoch 0 loss = 0.9580045938491821
# Epoch 1 loss = 0.9142596125602722
# Epoch 2 loss = 0.9040825366973877
# Epoch 3 loss = 0.8943553566932678
# Epoch 4 loss = 0.8919141292572021
# Epoch 5 loss = 0.8640949130058289
# Epoch 6 loss = 0.8526456952095032
# Epoch 7 loss = 0.830696165561676
# Epoch 8 loss = 0.8229963779449463
# Epoch 9 loss = 0.8010280728340149
# Epoch 10 loss = 0.7934720516204834
# Epoch 11 loss = 0.776760995388031
# Epoch 12 loss = 0.7700842618942261
# Epoch 13 loss = 0.7665451765060425
# Epoch 14 loss = 0.7518400549888611
# Epoch 15 loss = 0.7557094693183899
# Epoch 16 loss = 0.7444096803665161
# Epoch 17 loss = 0.7413851022720337
# Epoch 18 loss = 0.737515389919281
# Epoch 19 loss = 0.7354779839515686
# Epoch 20 loss = 0.7382456660270691
# Epoch 21 loss = 0.7323731780052185
# Epoch 22 loss = 0.7310827970504761
# Epoch 23 loss = 0.7357314825057983
# Epoch 24 loss = 0.7263075113296509
# Epoch 25 loss = 0.7269534468650818
# Epoch 26 loss = 0.7306941151618958
# Epoch 27 loss = 0.730445146560669
# Epoch 28 loss = 0.7267281413078308
# Epoch 29 loss = 0.7266073822975159
# Epoch 30 loss = 0.7227745652198792
# Epoch 31 loss = 0.7280823588371277
# Epoch 32 loss = 0.7265921235084534
# Epoch 33 loss = 0.7256133556365967
# Epoch 34 loss = 0.7298113703727722
# Epoch 35 loss = 0.723640501499176
# Epoch 36 loss = 0.7214124202728271
# Epoch 37 loss = 0.7188512682914734
# Epoch 38 loss = 0.7229625582695007
# Epoch 39 loss = 0.7222704887390137
# Epoch 40 loss = 0.7189231514930725
# Epoch 41 loss = 0.7246025800704956
# Epoch 42 loss = 0.716877818107605
# Epoch 43 loss = 0.7212201952934265
# Epoch 44 loss = 0.7209755182266235
# Epoch 45 loss = 0.7238718271255493
# Epoch 46 loss = 0.7129617929458618
# Epoch 47 loss = 0.7171102166175842
# Epoch 48 loss = 0.7227559089660645
# Epoch 49 loss = 0.7155703902244568
# Epoch 50 loss = 0.7200911045074463
# Epoch 51 loss = 0.7156051397323608
# Epoch 52 loss = 0.718994677066803
# Epoch 53 loss = 0.7198799848556519
# Epoch 54 loss = 0.7228724956512451
# Epoch 55 loss = 0.717623233795166
# Epoch 56 loss = 0.7191264033317566
# Epoch 57 loss = 0.7193270325660706
# Epoch 58 loss = 0.7216504812240601
# Epoch 59 loss = 0.7177922129631042
# Epoch 60 loss = 0.7204616665840149
# Epoch 61 loss = 0.7209935784339905
# Epoch 62 loss = 0.7187818288803101
# Epoch 63 loss = 0.7183143496513367
# Epoch 64 loss = 0.7175570726394653
# Epoch 65 loss = 0.7191588878631592
# Epoch 66 loss = 0.7170572876930237
# Epoch 67 loss = 0.7181280851364136
# Epoch 68 loss = 0.720672607421875
# Epoch 69 loss = 0.7232733368873596
# Epoch 70 loss = 0.7279032468795776
# Epoch 71 loss = 0.7165102958679199
# Epoch 72 loss = 0.7206578850746155
# Epoch 73 loss = 0.7202479243278503
# Epoch 74 loss = 0.7108650803565979
# Epoch 75 loss = 0.7179496884346008
# Epoch 76 loss = 0.714180052280426
# Epoch 77 loss = 0.7162683010101318
# Epoch 78 loss = 0.713848888874054
# Epoch 79 loss = 0.7163769602775574
# Epoch 80 loss = 0.7146938443183899
# Epoch 81 loss = 0.7216917276382446
# Epoch 82 loss = 0.7212717533111572
# Epoch 83 loss = 0.7233104705810547
# Epoch 84 loss = 0.7134410738945007
# Epoch 85 loss = 0.7172360420227051
# Epoch 86 loss = 0.7159969210624695
# Epoch 87 loss = 0.7186455726623535
# Epoch 88 loss = 0.7171348333358765
# Epoch 89 loss = 0.7185106873512268
# Epoch 90 loss = 0.7221867442131042
# Epoch 91 loss = 0.7272960543632507
# Epoch 92 loss = 0.718304455280304
# Epoch 93 loss = 0.7151879668235779
# Epoch 94 loss = 0.7170753479003906
# Epoch 95 loss = 0.708705723285675
# Epoch 96 loss = 0.7160314917564392
# Epoch 97 loss = 0.7156351804733276
# Epoch 98 loss = 0.7141625881195068
# Epoch 99 loss = 0.7121874094009399

# %% [markdown]
# ## Sampling algorithm

# %% [markdown]
# We will use the classic DDPM sampler, defined as follows

# %%
def sample(model, nsamples, nfeatures):
    """Sampler following the Denoising Diffusion Probabilistic Models method by Ho et al (Algorithm 2)"""
    with torch.no_grad():
        x = torch.randn(size=(nsamples, nfeatures)).to(device)
        xt = [x]
        for t in range(num_steps-1, 0, -1):
            predicted_noise = model(x, torch.full([nsamples, 1], t).to(device))

            x0  = denoise(x, predicted_noise, torch.tensor(t).to(device))

            if t > 1:
                x,_ = noise(x0, torch.tensor(t-1).to(device))
            xt += [x]
        return x, xt

# %% [markdown]
# ## Test generation

# %% [markdown]
# Let's generate 10K samples of the learned distribution using the diffusion model we just created

# %%
Xgen, Xgen_hist = sample(model, 10000, 2)
Xgen = Xgen.cpu()
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.scatter(Xgen[:, 0], Xgen[:, 1], marker="1", alpha=0.5)
plt.legend(["Original data", "Generated data"])
plt.xlim(-2.4, 2.4)
plt.ylim(-2.4, 2.4)
plt.xticks([-2, -1, 0, 1, 2])
plt.yticks([-2, -1, 0, 1, 2])
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
